# %%
from isda_streaming import TimedStream, KeyedStream, WindowedStream

data_fpath = "../data/autobahn.csv"
start = 0
end = 30
input_stream = TimedStream()
input_stream.from_csv(data_fpath, start, end)

print(input_stream)
# Out:
# TimedStream([((1.0, 80.0, 'lkw', 'Volvo'), 1590969600.0), ((2.0, 124.0, 'pkw', 'Nissan'), 1590969601.0), ((3.0, 202.0, 'pkw', 'VW'), 1590969602.0), ((1.0, 79.0, 'lkw', 'DAF'), 1590969606.0), ((2.0, 122.0, 'pkw', 'Skoda'), 1590969607.0), ((1.0, 80.0, 'lkw', 'Scania'), 1590969612.0), ((3.0, 213.0, 'pkw', 'Bugatti'), 1590969612.0), ((2.0, 129.0, 'pkw', 'VW'), 1590969613.0), ((1.0, 75.0, 'lkw', 'Scania'), 1590969618.0), ((2.0, 165.0, 'pkw', 'Bugatti'), 1590969619.0), ((3.0, 205.0, 'pkw', 'VW'), 1590969622.0), ((1.0, 80.0, 'lkw', 'MAN'), 1590969624.0), ((2.0, 170.0, 'pkw', 'Lamborghini'), 1590969625.0), ((1.0, 85.0, 'lkw', 'Iveco'), 1590969630.0), ((2.0, 130.0, 'pkw', 'Ford'), 1590969631.0), ((3.0, 239.0, 'pkw', 'Bentley'), 1590969632.0), ((1.0, 105.0, 'pkw', 'VW'), 1590969636.0), ((2.0, 145.0, 'pkw', 'Hyundai'), 1590969637.0), ((1.0, 80.0, 'lkw', 'MAN'), 1590969642.0), ((3.0, 282.0, 'pkw', 'Lamborghini'), 1590969642.0), ((2.0, 143.0, 'pkw', 'Opel'), 1590969643.0), ((1.0, 77.0, 'lkw', 'Iveco'), 1590969648.0), ((2.0, 138.0, 'pkw', 'Audi'), 1590969649.0), ((3.0, 197.0, 'pkw', 'Hyundai'), 1590969652.0), ((1.0, 79.0, 'lkw', 'MAN'), 1590969654.0), ((2.0, 132.0, 'pkw', 'Mercedes-Benz'), 1590969655.0), ((1.0, 84.0, 'lkw', 'Volvo'), 1590969660.0), ((2.0, 131.0, 'pkw', 'VW'), 1590969661.0), ((3.0, 198.0, 'pkw', 'Audi'), 1590969662.0), ((1.0, 83.0, 'lkw', 'Scania'), 1590969666.0), ((2.0, 128.0, 'pkw', 'Renault'), 1590969667.0)])
